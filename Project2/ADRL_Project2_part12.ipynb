# %% [markdown]
# Epoch [400/500]  rec_loss - 0.03958876058459282, adv_loss - 5.046255588531494
#
# Reconstructed Images
#
# ![image.png](attachment:image.png)
#
# Generated Images
#
# ![image-1.png](attachment:image-1.png)
#
# FID
#
# 100%|██████████| 17/17 [00:02<00:00,  5.88it/s]
#
# 100%|██████████| 17/17 [00:02<00:00,  5.73it/s]
#
# FID Score at epoch 400: 348.62605688879415
