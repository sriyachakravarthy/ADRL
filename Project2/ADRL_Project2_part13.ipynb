# %% [markdown]
# Epoch [600/2000]  rec_loss - 0.0306862723082304, adv_loss - 4.448071002960205
#
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-6.png](attachment:image-6.png)
#
# 100%|██████████| 17/17 [00:02<00:00,  5.85it/s]
#
# 100%|██████████| 17/17 [00:02<00:00,  5.71it/s]
#
# FID Score at epoch 600: 394.9583317827987
